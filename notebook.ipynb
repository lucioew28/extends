# %% [markdown]
# <a href="https://colab.research.google.com/github/lucioew28/extends/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# connect to google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = '/content/drive/My Drive/TCC/properties_list.csv'

df = pd.read_csv(file_path, sep=';', encoding='ISO-8859-1', skiprows=2)
df.head()
# Out:
#     N° do imóvel   UF                    Cidade                   Bairro  \
# 0  1444407165676  ES                   ARACRUZ               GUAXINDIBA
# 1  8444403788170  ES              BAIXO GUANDU                   CENTRO
# 2  8555535294312  ES   CACHOEIRO DE ITAPEMIRIM   SAO FRANCISCO DE ASSIS
# 3  8787702547640  ES   CACHOEIRO DE ITAPEMIRIM                SAO LUCAS
# 4  8555533439186  ES   CACHOEIRO DE ITAPEMIRIM   SAO FRANCISCO DE ASSIS
#
#                                             Endereço       Preço  \
# 0                         QUADRA 29, N. SN, LOTE 08   160.000,54
# 1                    RUA ANTONIO SAMPAIO, N. 343, A   150.000,00
# 2  RUA OZIL PASSONI N 104 407 01, N. 104, Apto 40...   84.000,00
# 3  AVENIDA LEOPOLDINA SMARZARO, N. 322, Apto 308,...   79.800,00
# 4      RUA JOAO PESSINI, N. 218, Apto 402, BLOCO 02   152.460,00
#
#   Valor de avaliação  Desconto  \
# 0         145.000,00       0.0
# 1         115.000,00       0.0
# 2         140.000,00      40.0
# ...
